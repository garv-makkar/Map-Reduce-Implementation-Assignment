# %%
import pandas as pd
import numpy as np

# read text file of points
points = pd.read_csv('points.txt', header=None, sep=',', names=['x', 'y'])

points
# Out:
#        x    y
# 0    0.4  7.2
# 1    0.8  9.8
# 2   -1.5  7.3
# 3    8.1  3.4
# 4    7.3  2.3
# 5    9.1  3.1
# 6    8.9  0.2
# 7   11.5 -1.9
# 8   10.2  0.5
# 9    9.8  1.2
# 10   8.5  2.7
# 11  10.3 -0.3
# 12   9.7  0.8
# 13   8.3  2.9
# 14   0.0  7.1
# 15   0.9  9.6
# 16  -1.6  7.4
# 17   0.3  7.2
# 18   0.7  9.9
# 19  -1.7  7.5
# 20   0.5  7.4
# 21   0.9  9.7
# 22  -1.8  7.6
# 23  11.1 -1.5
# 24  10.8 -0.6
# 25   9.5  1.5
# 26   8.7  2.4
# 27  11.2 -1.2
# 28  10.5 -0.1
# 29   9.3  1.9
# 30   8.6  2.6

# %%
# plot these points
import matplotlib.pyplot as plt
plt.scatter(points.x, points.y)
plt.show()

# %%
# plot these points
x1 = -0.175
y1 = 8.14

x2 = 8.6
y2 = 2.53

x3 = 10.4
y3 = -0.29

# plot these points on above plot
plt.scatter(points.x, points.y)
plt.scatter(x1, y1, color='red')
plt.scatter(x2, y2, color='red')
plt.scatter(x3, y3, color='red')
plt.show()
